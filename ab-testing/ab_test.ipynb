# %% [markdown]
# # A/B Тестирование маркетинговой кампании
#
# ## Цель проекта
# Оценка эффективности новой маркетинговой кампании.
#
# ## Метрики
# - Конверсия
# - Средний чек
# - Retention rate
#
# ## Результаты
# Конверсия увеличилась на **15%** (p-value < 0.05)

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

print('A/B тестирование выполнено успешно')
